# %% [markdown]
# # Zero to Hero in python programming in 60 days
# ## Conditions
# Conditions always evaluate down to a Boolean value, True or False. A flow control statement decides what to do based on whether its condition is True or False, and
# almost every flow control statement uses a condition.

# %% [markdown]
# Rules of Blocks of Code
# 1. Blocks begin when the indentation increases.
# 2. Blocks can contain other blocks.
# 3. Blocks end when the indentation decreases to zero or to a containing block’s indentation.

# %%
name='Aba1ss'
password='swo1rdfish'
age=3

# %%
if name == 'Abass':
    print('Hello Abass')
    if password == 'swordfish':
        print('Access granted.')
else:
    print('Wrong password.')
# Out:
# Hello Abass
# Wrong password.

# %% [markdown]
# #### If statement
# In Python, an if statement consists of
# the following:
#
# •	 The if keyword
#
# •	 A condition (that is, an expression that evaluates to True or False)
#
# •	 A colon
#
# •	 Starting on the next line, an indented block of code (called the if clause)

# %%
if name == 'Abass':
    print('Hi, Abass.')

# %% [markdown]
# #### Else statement
# An else statement doesn’t have a condition, and in code, an else statement always consists of the following:
#
# •	 The else keyword
#
# •	 A colon
#
# •	 Starting on the next line, an indented block of code (called the else clause)

# %%
if name == 'Olaiya':
    print('Hi, Olaiya.')
else:
    print('Hello, stranger.')
# Out:
# Hello, stranger.

# %% [markdown]
# #### elif
# an elif statement always consists of the following:
#
# •	 The elif keyword
#
# •	 A condition (that is, an expression that evaluates to True or False)
#
# •	 A colon
#
# •	 Starting on the next line, an indented block of code (called the elif clause)

# %%
if name == 'Abel':
    print('Hi, Abel.')
elif age < 12:
    print('You are not Abel, kiddo.')
# Out:
# You are not Abel, kiddo.

# %%
if name == 'Abel':
    print('Hi, Abel.')
elif age < 12:
    print('You are not Abel, kiddo.')
elif age > 2000:
    print('Unlike you, Abel is not an undead, immortal vampire.')
elif age > 100:
    print('You are not Abel, grannie.')

# %%
if name == 'Abel':
    print('Hi, Abel.')
elif age < 12:
    print('You are not Abel, kiddo.')
else:
    print('You are neither Abel nor a little kid.')
# Out:
# You are not Abel, kiddo.

# %% [markdown]
# #### While loop
#
# a while statement always consists of the following:
#
# •	 The while keyword
#
# •	 A condition (that is, an expression that evaluates to True or False)
#
# •	 A colon
#
# •	 Starting on the next line, an indented block of code (called the while clause)

# %%
age = 0
if age < 5:
    print('Hello, world.')
    age = age + 1
# Out:
# Hello, world.

# %%
age
# Out:
# 1

# %%
age = 0
while age < 5:
    print('Hello, world.' + str(age))
# Out:
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# Hello, world.0
# ...

# %%
name = ''
while name != 'your name':
    name = input('Please type your name.')
print('Thank you!')
# Out:
# Please type your name.Abass Olaiya
# Please type your name.Omolade Jumoke
# Please type your name.your name
# Thank you!

# %% [markdown]
# break statement
#
# If the execution reaches a break statement, it immediately exits the while loop’s clause.

# %%
trials = 0
name = ''
while name != 'your name':
    name = input('Please type your name.')
    trials = trials + 1
    if trials > 5:
        print('You failed dummy')
        break
print('Thank you!')
# Out:
# Please type your name.abass
# Please type your name.olaiya
# Please type your name.tolu
# Please type your name.jumoke
# Please type your name.bolade
# Please type your name.pelumi
# You failed dummy
# Thank you!

# %% [markdown]
# continue Statements
#
#  When the program execution reaches a continue statement, the program execution immediately jumps back to the start of the loop and reevaluates the loop’s condition. (This is also what happens when the execution reaches the end of the loop.)

# %%
while True:
    name = input('Who are you?')
    if name != 'Joe':
        continue
    password = input('Hello, Joe. What is the password? (It is a fish.)')
    if password == 'swordfish':
            break
print('Access granted.')
# Out:
# Who are you?Joe
# Hello, Joe. What is the password? (It is a fish.)kote
# Who are you?Joe
# Hello, Joe. What is the password? (It is a fish.)swordfish
# Access granted.

# %% [markdown]
# for Loops and the range() Function
#
# a for statement looks something like for i in range(5): and always includes the following:
#
# •	 The for keyword
#
# •	 A variable name
#
# •	 The in keyword
#
# •	 A call to the range() method with up to three integers passed to it
#
# •	 A colon
#
# •	 Starting on the next line, an indented block of code (called the for clause)

# %%
print('My name is')
for i in range(5):
    print('Olaiya Five Times (' + str(i) + ')')

# %%
total = 0
for num in range(101):
    total = total + num
print(total)

# %%
trials = 0
name = ''
while name != 'your name':
    name = input('Please type your name.')
    trials = trials + 1
    if trials > 5:
        print('You failed dummy')
        break
print('Thank you!')
# Out:
# Please type your name.your name
# Thank you!

# %%
#If we will rewrite this
for trial in range(5):
    name = input('please type your name.')
    if name == 'your name':
        break
print('Thank you')
# Out:
# please type your name.your name
# Thank you

# %% [markdown]
# The Starting, Stopping, and Stepping arguments to range()

# %%
for i in range(12, 16):
    print(i)
# Out:
# 12
# 13
# 14
# 15

# %%
for i in range(0, 10, 2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
for i in range(5, -1, -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# #### importing modules
# built-in functions
#
# standard library
#
# An import statement consists of the following:
#
# •	 The import keyword
#
# •	 The name of the module
#
# •	 Optionally, more module names, as long as they are separated by commas

# %%
import random
for i in range(5):
    print(random.randint(1, 10))
# Out:
# 3
# 4
# 8
# 1
# 1

# %%
import random, sys, os, math

# %%
from random import randint

# %% [markdown]
# from import Statements

# %%
randint(1,10)
# Out:
# 5

# %%
from random import *

# %% [markdown]
# ### Assignment
# Write a short program that prints even numbers betwee 1 and 100 using a for loop.
# Then write an equivalent program that prints even numbers betwee 1 and 100 using a while loop.
#
# Look up the round() and abs() functions on the Internet
